# %% [markdown]
# ## Домашнее задание к лекции «Функции»

# %%
# Перечень всех документов

documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# Перечень полок, на которых хранятся документы

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}

# MAIN

def main():
    
    while True:
        user_input = input('Введите команду:')  
        if user_input == 'p':
            get_name(documents)
        elif user_input == 's':
            get_rack(directories)
        elif user_input == 'l':
            get_data(documents, directories)
        elif user_input == 'as':
            get_more_rack(directories)
        elif user_input == 'ds':
            get_del_rack(directories)
        elif user_input == 'q':
            return print('bye bye')
        else:
            print('Неверная команда. Для Выхода Введите "q"')
            
  



# Пункт 1 Пользователь по команде “p” может узнать владельца документа по его номеру

def get_name(all_docs):
    element = str(input('Введите номер документа:'))
    for member in documents:
        if element == member['number']: # равно а не in т.к. во вхождении может браться часть числа, можно ли сделать чтобы бралось целым с in ?
            return print (f'Владелец документа:', member['name'])  
    else:
        print('Документ не найден в базе')
        

# Пункт 2 Пользователь по команде “s” может по номеру документа узнать на какой полке он хранится

def get_rack(all_dicts):
    element = str(input('Введите номер документа:'))
    for rack, docs in directories.items():
        if element in list(docs):
            return print(f'Документ хранится на полке:', rack)  
    else:
        print('Документ не найден в базе')
        


# Пункт 3 Пользователь по команде “l” может увидеть полную информацию по всем документам

def get_data(all_info, alla):
    for rack, docs in directories.items():
         for member in documents:
                if member["number"] in docs:
                    print(f'№: {member["number"]}, Тип: {member["type"]}, владелец: {member["name"]}, полка хранения: {rack}')
                 
# Пункт 4 Пользователь по команде “as” может добавить новую полку

def get_more_rack(all_dscts):
    for rack, docs in list(directories.items()):
        add_rack_input = str(input('Введите номер полки:'))
        if add_rack_input in list(directories.keys()):
            print(f'Такая полка уже существует. Текущий перечень полок:{", ".join(directories.keys())}')
        else:
            directories[add_rack_input] = []
            print(f'{", ".join(directories.keys())}')
            print(f'Полка добавлена. Текущий перечень полок:{", ".join(directories.keys())}')
        break
        
       


# Пункт 5 Пользователь по команде “ds” может удалить существующую полку из данных (только если она пустая)

def get_del_rack(all_dscts):
    for rack, docs in list(directories.items()):
        add_rack_input = str(input('Введите номер полки:'))
        if  directories.get(add_rack_input, 'Not found') == []:
                del(directories[add_rack_input]) 
                print(f'Полка удалена. Текущий перечень полок:{", ".join(directories.keys())}')    
        elif add_rack_input in list(directories.keys()):
            print(f'На полке есть документы удате их перед удалением полки. Текущий перечень полок:{", ".join(directories.keys())}')      
        else:            
            print(f'Такой полки не существует. Текущий перечень полок:{", ".join(directories.keys())}')
        break
 
main()
# Out:
# Введите команду:as
# Введите номер полки:1
# Такая полка уже существует. Текущий перечень полок:1, 2, 3
# Введите команду:1
# Неверная команда. Для Выхода Введите "q"
# Введите команду:q
# bye bye
